# %% [markdown]
# notebook showing how **d3fdgraph** is used.

# %%
# import the d3fdgraph and datasort library
import d3fdgraph_lab
import datasort_lab

# %%
file_name = "transitions.csv"

subject_list = datasort_lab.subject_list(file_name)
subject = subject_list[10]
data_set = datasort_lab.data_sorter(file_name,subject)
state_name = datasort_lab.state_name(file_name,subject)
coordinates = [(300,300),(500,200),(400,200),(600,300),(500,300),(400,300),(500,400)]

# %%
''' 
Example parameters
d3fdgraph.plot_force_directed_graph(data_set,
                                    state_name=state_name,
                                    image=image,
                                    colour=colour,
                                    zoom=True,
                                    coordinates=coordinates)
'''

d3fdgraph_lab.plot_force_directed_graph(data_set,
                                    state_name=state_name,
                                    image=None,
                                    coordinates=coordinates)
# Out:
# <div id="d3-container-03a6f545-6de6-4c51-a5a1-eafce7e4f94d"></div>
#
# <style>
#     .links path {
#         fill: none;
#     }
#     .nodes rect {
#         pointer-events: all;
#         stroke: #fff;
#         stroke-width: 1px;
#         opacity: 1.0;
#     }
#     .nodes text {
#         pointer-events: none;
#         font: 8px sans-serif;
#         fill: #fff;
#         stroke-width: 0.6px;
#         opacity: 1.0;
#     }
# </style>
#
# <button id="saveButton">Save SVG</button>
#
# <p>Data Select:
# <input type="range" min="0", max="281", step="1", value="0" id="dataSelect"/>
# <output id="dataIndexOutput"></output>
# <output id="dataDateOutput"></output>
# </p>
#
# <p>Link Pruning Threshold:
# <input type="range" min="0", max="1", step="0.01", value="0" id="linkThreshold"/>
# <output id="linkThresholdOutput">0</output>
# </p>
